# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
plt.style.use('seaborn-colorblind')
plt.ion()

# %%
movies = pd.read_csv("/content/drive/MyDrive/icd-proj/IMDb movies.csv")
movies.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   imdb_title_id  ... reviews_from_critics
# 0     tt0000009  ...                  2.0
# 1     tt0000574  ...                  7.0
# 2     tt0001892  ...                  2.0
# 3     tt0002101  ...                  3.0
# 4     tt0002130  ...                 14.0
#
# [5 rows x 22 columns]

# %%
movies_notnull = movies.dropna()
movies_notnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6616 entries, 506 to 85740
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          6616 non-null   object
#  1   title                  6616 non-null   object
#  2   original_title         6616 non-null   object
#  3   year                   6616 non-null   object
#  4   date_published         6616 non-null   object
#  5   genre                  6616 non-null   object
#  6   duration               6616 non-null   int64
#  7   country                6616 non-null   object
#  8   language               6616 non-null   object
#  9   director               6616 non-null   object
#  10  writer                 6616 non-null   object
#  11  production_company     6616 non-null   object
#  12  actors                 6616 non-null   object
#  13  description            6616 non-null   object
# ...

# %%
names = pd.read_csv("/content/drive/MyDrive/icd-proj/IMDb names.csv")
names.head()
# Out:
#   imdb_name_id             name  ... spouses_with_children  children
# 0    nm0000001     Fred Astaire  ...                     1         2
# 1    nm0000002    Lauren Bacall  ...                     2         3
# 2    nm0000003  Brigitte Bardot  ...                     1         1
# 3    nm0000004     John Belushi  ...                     0         0
# 4    nm0000005   Ingmar Bergman  ...                     5         8
#
# [5 rows x 17 columns]

# %%
ratings = pd.read_csv("/content/drive/MyDrive/icd-proj/IMDb ratings.csv")
ratings.head()
# Out:
#   imdb_title_id  ...  non_us_voters_votes
# 0     tt0000009  ...                 70.0
# 1     tt0000574  ...                331.0
# 2     tt0001892  ...                123.0
# 3     tt0002101  ...                105.0
# 4     tt0002130  ...               1166.0
#
# [5 rows x 49 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdb_title_id              85855 non-null  object
#  1   weighted_average_vote      85855 non-null  float64
#  2   total_votes                85855 non-null  int64
#  3   mean_vote                  85855 non-null  float64
#  4   median_vote                85855 non-null  float64
#  5   votes_10                   85855 non-null  int64
#  6   votes_9                    85855 non-null  int64
#  7   votes_8                    85855 non-null  int64
#  8   votes_7                    85855 non-null  int64
#  9   votes_6                    85855 non-null  int64
#  10  votes_5                    85855 non-null  int64
#  11  votes_4                    85855 non-null  int64
#  12  votes_3                    85855 non-null  int64
# ...

# %%
title = pd.read_csv("/content/drive/MyDrive/icd-proj/IMDb title_principals.csv")
title.head()
# Out:
#   imdb_title_id  ...                                         characters
# 0     tt0000009  ...           ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1     tt0000009  ...                                   ["Mr. Hamilton"]
# 2     tt0000009  ...  ["Chauncey Depew - the Director of the New Yor...
# 3     tt0000009  ...                                                NaN
# 4     tt0000574  ...                                     ["Kate Kelly"]
#
# [5 rows x 6 columns]

# %% [markdown]
# Podemos analisar desse dataset o que de fato uma nota diz sobre um filme, analisando quão rara é tal nota quando tiramos a média de notas da população. Por exemplo, a partir disso, podemos formular a seguinte hipótese: uma nota média 8 diz pouco sobre a qualidade de um filme, já que ela é bem comum na base de dados. Tentaremos a partir daqui buscar evidências em dados que confirmem ou descartem essa ideia.
#
# Uma maneira de testar essa hipótese é construir um intervalo de confiança utilizando a técnica de bootstrap, estratégia que será utilizada aqui.

# %%
def bootstrap(dataframe, N, sample_size):
  values = np.zeros(N)
  for i in range(N):
        sample = dataframe.sample(sample_size, replace=True)
        values[i] = sample.mean()
  return values

# %% [markdown]
# Aplicando o bootstrap na coluna com os dados desejados:

# %%
result = bootstrap(ratings['mean_vote'], 10000, 1000)
result
# Out:
# array([6.2614, 6.1998, 6.173 , ..., 6.2456, 6.2311, 6.2618])

# %% [markdown]
# Plotando o resultado - Note como o resultado obtido se aproxima de uma distribuição normal:

# %%
plt.figure(figsize=(13,8))
plt.hist(result, bins=40, edgecolor='k', density=True)
res = norm(loc=result.mean(), scale=result.std())
res_np = np.linspace(res.ppf(0.001), res.ppf(0.999),10000)
plt.plot(res_np, res.pdf(res_np))
plt.xlabel('Média de avaliação')
plt.ylabel('P[Média]')
plt.show()

# %% [markdown]
# A maior concentração de valores se encontra entre 6.15 e 6.30, como mostrado abaixo:

# %%
plt.figure(figsize=(13,8))
plt.plot(res_np, res.pdf(res_np))
filler = np.linspace(np.percentile(result, 2.5),np.percentile(result, 97.5))
plt.fill_between(filler, res.pdf(filler), color='r', alpha=0.5)
plt.xlabel('Média de avaliação')
plt.ylabel('P(Média)')
plt.show()

# %% [markdown]
# Como o valor apresentado na hipótese, 8, encontra-se fora dessa área, temos que ele é um valor de rara ocorrência e portanto, a hipótese é rejeitada, uma vez que um filme não apresenta média igual a ele frequentemente.
